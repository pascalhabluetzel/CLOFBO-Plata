# %%
import pandas as pd
from rdflib import Graph, Literal, RDF, Namespace, BNode
from rdflib.namespace import FOAF, XSD

# Load CSV data
df = pd.read_csv('../Data/Datos_CLOFBO-Plata.tsv', sep='\t', encoding='ISO-8859-1')

# Define Namespaces
FOAF = Namespace("http://xmlns.com/foaf/0.1/")
DC = Namespace("https://www.dublincore.org/specifications/dublin-core/dcmi-terms/")
DWC = Namespace("http://rs.tdwg.org/dwc/terms/")

# Create an RDF graph
g = Graph()

# Bind namespaces to the graph
g.bind("foaf", FOAF)
g.bind("dc", DC)
g.bind("dwc", DWC)

# Add data from CSV to RDF graph
for index, row in df.iterrows():
    agent = BNode()
    g.add((agent, RDF.type, FOAF.Agent))
    if pd.notna(row['dc_type']):
        g.add((agent, DC.dc_type, Literal(row['dc_type'], datatype=XSD.string)))
    if pd.notna(row['dc_modified']):
        g.add((agent, DC.dc_modified, Literal(row['dc_modified'], datatype=XSD.string)))
    if pd.notna(row['dc_bibliographicCitation']):
        g.add((agent, DC.dc_bibliographicCitation, Literal(row['dc_bibliographicCitation'], datatype=XSD.string)))
    if pd.notna(row['dwc_basisOfRecord']):
        g.add((agent, DWC.dwc_basisOfRecord, Literal(row['dwc_basisOfRecord'], datatype=XSD.string)))
    if pd.notna(row['dwc_catalogNumber']):
        g.add((agent, DWC.dwc_catalogNumber, Literal(row['dwc_catalogNumber'], datatype=XSD.string)))
    if pd.notna(row['dwc_recordNumber']):
        g.add((agent, DWC.dwc_recordNumber, Literal(row['dwc_recordNumber'], datatype=XSD.string)))
    if pd.notna(row['dwc_recordedBy']):
        g.add((agent, DWC.dwc_recordedBy, Literal(row['dwc_recordedBy'], datatype=XSD.string)))
    if pd.notna(row['dwc_individualCount']):
        g.add((agent, DWC.dwc_individualCount, Literal(row['dwc_individualCount'], datatype=XSD.string)))
    if pd.notna(row['dwc_sex']):
        g.add((agent, DWC.dwc_sex, Literal(row['dwc_sex'], datatype=XSD.string)))
    if pd.notna(row['dwc_occurrenceStatus']):
        g.add((agent, DWC.dwc_occurrenceStatus, Literal(row['dwc_occurrenceStatus'], datatype=XSD.string)))
    if pd.notna(row['dwc_eventDate']):
        g.add((agent, DWC.dwc_eventDate, Literal(row['dwc_eventDate'], datatype=XSD.string)))
    if pd.notna(row['dwc_verbatimEventDate']):
        g.add((agent, DWC.dwc_verbatimEventDate, Literal(row['dwc_verbatimEventDate'], datatype=XSD.string)))
    if pd.notna(row['dwc_waterBody']):
        g.add((agent, DWC.dwc_waterBody, Literal(row['dwc_waterBody'], datatype=XSD.string)))
    if pd.notna(row['dwc_country']):
        g.add((agent, DWC.dwc_country, Literal(row['dwc_country'], datatype=XSD.string)))
    if pd.notna(row['dwc_countryCode']):
        g.add((agent, DWC.dwc_countryCode, Literal(row['dwc_countryCode'], datatype=XSD.string)))
    if pd.notna(row['dwc_county']):
        g.add((agent, DWC.dwc_county, Literal(row['dwc_county'], datatype=XSD.string)))
    if pd.notna(row['dwc_municipality']):
        g.add((agent, DWC.dwc_municipality, Literal(row['dwc_municipality'], datatype=XSD.string)))
    if pd.notna(row['dwc_locality']):
        g.add((agent, DWC.dwc_locality, Literal(row['dwc_locality'], datatype=XSD.string)))
    if pd.notna(row['dwc_verbatimLocality']):
        g.add((agent, DWC.dwc_verbatimLocality, Literal(row['dwc_verbatimLocality'], datatype=XSD.string)))
    if pd.notna(row['dwc_verbatimElevation']):
        g.add((agent, DWC.dwc_verbatimElevation, Literal(row['dwc_verbatimElevation'], datatype=XSD.string)))
    if pd.notna(row['dwc_verbatimCoordinateSystem']):
        g.add((agent, DWC.dwc_verbatimCoordinateSystem, Literal(row['dwc_verbatimCoordinateSystem'], datatype=XSD.string)))
    if pd.notna(row['dwc_verbatimCoordinates']):
        g.add((agent, DWC.dwc_verbatimCoordinates, Literal(row['dwc_verbatimCoordinates'], datatype=XSD.string)))
    if pd.notna(row['dwc_verbatimLatitude']):
        g.add((agent, DWC.dwc_verbatimLatitude, Literal(row['dwc_verbatimLatitude'], datatype=XSD.string)))
    if pd.notna(row['dwc_verbatimLongitude']):
        g.add((agent, DWC.dwc_verbatimLongitude, Literal(row['dwc_verbatimLongitude'], datatype=XSD.string)))
    if pd.notna(row['dwc_family']):
        g.add((agent, DWC.dwc_family, Literal(row['dwc_family'], datatype=XSD.string)))
    if pd.notna(row['dwc_scientificName']):
        g.add((agent, DWC.dwc_scientificName, Literal(row['dwc_scientificName'], datatype=XSD.string)))
    if pd.notna(row['dwc_originalNameUsage']):
        g.add((agent, DWC.dwc_originalNameUsage, Literal(row['dwc_originalNameUsage'], datatype=XSD.string)))
    if pd.notna(row['dwc_verbatimIdentification']):
        g.add((agent, DWC.dwc_verbatimIdentification, Literal(row['dwc_verbatimIdentification'], datatype=XSD.string)))
    if pd.notna(row['dwc_identifiedBy']):
        g.add((agent, DWC.dwc_identifiedBy, Literal(row['dwc_identifiedBy'], datatype=XSD.string)))
    if pd.notna(row['dwc_typeStatus']):
        g.add((agent, DWC.dwc_typeStatus, Literal(row['dwc_typeStatus'], datatype=XSD.string)))
    if pd.notna(row['dwc_MeasurementOrFact']):
        g.add((agent, DWC.dwc_MeasurementOrFact, Literal(row['dwc_MeasurementOrFact'], datatype=XSD.string)))
    if pd.notna(row['dwc_measurementValue']):
        g.add((agent, DWC.dwc_measurementValue, Literal(row['dwc_measurementValue'], datatype=XSD.string)))
    if pd.notna(row['dwc_measurementUnit']):
        g.add((agent, DWC.dwc_measurementUnit, Literal(row['dwc_measurementUnit'], datatype=XSD.string)))

# Prepare JSON-LD with explicit context
context = {
    "foaf": "http://xmlns.com/foaf/0.1/",
    "dwc": "http://rs.tdwg.org/dwc/terms/",
    "xsd": "http://www.w3.org/2001/XMLSchema#",
    "dc": "https://www.dublincore.org/specifications/dublin-core/dcmi-terms/"
}    
    
# Serialize graph to JSON-LD
jsonld_data = g.serialize(format='json-ld', indent=4, context=context)

# Write JSON-LD to file
with open("../Data/data.jsonld", "w", encoding='ISO-8859-1') as f:
    f.write(jsonld_data)

# Open JSON-LD with the right encoding
with open("../Data/data.jsonld", "r", encoding='ISO-8859-1') as f:
    jsonld_data = f.read()

# Load JSON-LD file into a new graph
g_jsonld = Graph()
g_jsonld.parse(data=jsonld_data, format="json-ld")

# SPARQL Query with the correct prefixes
sparql_query = """
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX dwc: <http://rs.tdwg.org/dwc/terms/>
    PREFIX dc: <https://www.dublincore.org/specifications/dublin-core/dcmi-terms/>

    SELECT ?dwc_scientificName ?dwc_family ?dwc_verbatimIdentification ?dc_type ?dwc_catalogNumber ?dwc_occurrenceStatus WHERE {
        # ?agent a foaf:Agent ;
               dwc:dwc_scientificName ?dwc_scientificName ;
               dwc:dwc_family ?dwc_family ;
               dc:dc_type ?dc_type ; 
               dwc:dwc_occurrenceStatus ?dwc_occurrenceStatus .
               
    OPTIONAL { ?agent a foaf:Agent ;
                dwc:dwc_catalogNumber ?dwc_catalogNumber ;
                dwc:dwc_verbatimIdentification ?dwc_verbatimIdentification . }
    }
"""

# Execute SPARQL query
results = g_jsonld.query(sparql_query)

# Print results
for row in results:
    print(f"{row['dwc_scientificName']}")
# Out:
# Pterygoplichthys ambrosettii (Holmberg 1893)
# Characidae Latreille 1825
# Osteogaster microps (Eigenmann & Kennedy 1903)
# Pachyurus bonariensis Steindachner 1879
# Cichlidae
# Cheirodon Girard 1855
# Rineloricaria catamarcensis (Berg 1895)
# Gymnotus carapo Linnaeus 1758
# Auchenipterus nuchalis (Spix & Agassiz 1829)
# Pyrrhulina australis Eigenmann & Kennedy 1903
# Chaetobranchopsis australis Eigenmann & Ward 1907
# Thoracocharax stellatus (Kner 1858)
# Bujurquina Kullander 1986
# Serrapinnus calliurus (Boulenger 1900)
# Loricaria Linnaeus 1758
# Metynnis mola Eigenmann & Kennedy 1903
# Aphyocharax anisitsi Eigenmann & Kennedy 1903
# Roeboides affinis (Günther 1868)
# Mylossoma duriventre (Cuvier 1818)
# Serrasalmus marginatus Valenciennes 1837
# Brachyhypopomus Mago-Leccia 1994
# Trichomycterus balzanii (Perugia 1891)
# Chaetobranchopsis australis Eigenmann & Ward 1907
# Rhamdia quelen (Quoy & Gaimard 1824)
# Rineloricaria phoxocephala (Eigenmann & Eigenmann 1889)
# Leporinus friderici (Bloch 1794)
# Apistogramma trifasciata (Eigenmann & Kennedy 1903)
# Gymnotus carapo Linnaeus 1758
# Poptella paraguayensis (Eigenmann 1907)
# Loricaria Linnaeus 1758
# Prodontocharax Eigenmann & Pearson 1924
# Charax gibbosus (Linnaeus 1758)
# Poecilia hasemani (Henn 1916)
# Rineloricaria catamarcensis (Berg 1895)
# Pimelodella gracilis (Valenciennes 1835)
# Imparfinis guttatus (Pearson 1924)
# Platydoras Bleeker 1862
# Hemigrammus Gill 1858
# Sorubim lima (Bloch & Schneider 1801)
# Markiana nigripinnis (Perugia 1891)
# Brachyhypopomus brevirostris (Steindachner 1868)
# Rineloricaria Bleeker 1862
# Hemiodus orthonops Eigenmann & Kennedy 1903
# Psalidodon fasciatus (Cuvier 1819)
# Hoplias malabaricus (Bloch 1794)
# Pterolebias Garman 1895
# Pimelodella cristata (Müller & Troschel 1849)
# Gymnotus carapo Linnaeus 1758
# Hoplosternum littorale (Hancock 1828)
# Bunocephalus doriae Boulenger 1902
# Ageneiosus inermis (Linnaeus 1766)
# Bryconops Kner 1858
# Apistogramma borellii (Regan 1906)
# Trachelyopterus Valenciennes 1840
# Steindachnerina dobula (Günther 1868)
# Leporinus Agassiz 1829
# Aphyocharax gracilis Fowler 1940
# Steindachnerina brevipinna (Eigenmann & Eigenmann 1889)
# Pimelodus maculatus Lcepède 1803
# Characidium laterale (Boulenger 1895)
# Rineloricaria steinbachi (Regan 1906)
# Brachyhypopomus brevirostris (Steindachner 1868)
# Hypostomus borellii (Boulenger 1897)
# Moenkhausia dichroura (Kner 1858)
# Hoplisoma polystictum (Regan 1912)
# Rhinodoras dorbignyi (Kner 1855)
# Lycengraulis Günther 1868
# Odontostilbe microcephala Eigenmann 1907
# Steindachnerina brevipinna (Eigenmann & Eigenmann 1889)
# Pygocentrus nattereri Kner 1858
# Serrasalmus Lacepède 1803
# Pygocentrus nattereri Kner 1858
# Trichomycterus duellmani Arratia & Menu-Marque 1984
# Crenicichla semifasciata (Heckel 1840)
# Psalidodon alleni (Eigenmann & McAtee 1907)
# Steindachnerina brevipinna (Eigenmann & Eigenmann 1889)
# Megalamphodus eques (Steindachner 1882)
# Pyrrhulina australis Eigenmann & Kennedy 1903
# Phenacogaster tegatus (Eigenmann 1911)
# Myloplus rubripinnis (Müller & Troschel 1844)
# Rhamphichthys pantherinus Castelnau 1855
# Loricaria luciae Thomas, Rodriguez, Carvallaro, Froehlich & Castro
# Synbranchus marmoratus Bloch 1795
# Trachelyopterus galeatus (Linnaeus)
# Zungaro zungaro (Humboldt 1821)
# Megaleporinus obtusidens (Valenciennes 1837)
# Apistogramma taeniata (Günther 1862)
# Hoplias malabaricus (Bloch 1794)
# Pimelodus Lacepède 1803
# Tatia Miranda Ribeiro 1911
# Otocinclus vestitus Cope 1872
# Saxatilia lepidota (Heckel 1840)
# Poecilia hasemani (Henn 1916)
# Apistogramma borellii (Regan 1906)
# Astyanax Baird & Girard 1854
# Aphyocharax Günther 1868
# Prionobrama paraguayensis (Eigenmann 1914)
# Brycon hilarii (Valenciennes 1850)
# Saxatilia lepidota (Heckel 1840)
# Synbranchus marmoratus Bloch 1795
# Astyanax Baird & Girard 1854
# Gymnotus carapo Linnaeus 1758
# Otocinclus vittatus Regan 1904
# Osteogaster microps (Eigenmann & Kennedy 1903)
# Platydoras costatus (Linnaeus 1758)
# Pellona flavipinnis (Valenciennes 1837)
# Pimelodella Eigenmann & Eigenmann 1888
# Astyanacinus moorii (Boulenger 1892)
# Bryconamericus iheringii (Boulenger 1887)
# Trachelyopterus galeatus (Linnaeus)
# Megaleporinus trifasciatus (Steindachner 1876)
# Piabina argentea Reinhardt 1867
# Ctenobrycon kennedyi (Eigenmann 1903)
# Crenicichla 1840
# Megaleporinus obtusidens (Valenciennes 1837)
# Bujurquina vittata (Heckel 1840)
# Holoshesthes pequira (Steindachner 1882)
# Moenkhausia dichroura (Kner 1858)
# Serrasalmus Lacepède 1803
# Cichlasoma portalegrense (Hensel 1870)
# Bujurquina oenolaemus Kullander 1987
# Cetopsis starnesi Vari, Ferraris & de Pinna 2005
# Myloplus levis (Eigenmann & McAtee 1907)
# Eigenmannia virescens (Valenciennes 1836)
# Moenkhausia dichroura (Kner 1858)
# Auchenipterus nigripinnis (Boulenger 1895)
# Lebiasinidae
# Odontostilbe microcephala Eigenmann 1907
# Astyanax lineatus (Perugia 1891)
# Piabarchus stramineus (Eigenmann 1908)
# Hyphessobrycon Durbin 1908
# Hemisorubim platyrhynchos (Valenciennes 1840)
# Pseudoplatystoma fasciatum (Linnaeus 1766)
# Poeciliidae
# Hypostomus borellii (Boulenger 1897)
# Odontostilbe Cope 1870
# Sturisoma Swainson 1838
# Prochilodus lineatus (Valenciennes 1837)
# Microglanis Eigenmann 1912
# Corydoras Lacepède 1803
# Pseudoplatystoma corruscans (Spix & Agassiz 1829)
# Acestrorhynchus altus Menezes 1969
# Cyphocharax gillii (Eigenmann & Kennedy 1903)
# Steindachnerina binotata (Pearson 1924)
# Characidium Reinhardt 1867
# Megalechis Reis 1997
# Megalechis thoracata (Valenciennes 1840)
# Tetragonopterus argenteus Cuvier 1816
# Odontostilbe paraguayensis Eigenmann & Kennedy 1903
# Cichlasoma dimerus (Heckel 1840)
# Geophagus Heckel 1840
# Acestrorhynchus altus Menezes 1969
# Trachelyopterus galeatus (Linnaeus)
# Megalechis thoracata (Valenciennes 1840)
# Trichomycterus corduvensis Weyenbergh 1877
# Pterygoplichthys ambrosettii (Holmberg 1893)
# Entomocorus benjamini Eigenmann 1917
# Brachyhypopomus Mago-Leccia 1994
# Serrasalmus spilopleura 1858
# Trichomycterus atochae (Allen 1942)
# Hypoptopoma Günther 1868
# Poecilia hasemani (Henn 1916)
# Poeciliidae
# Moenkhausia dichroura (Kner 1858)
# Lebiasinidae
# Crenicichla vittata Heckel 1840
# Prochilodus nigricans Spix & Agassiz 1829
# Characidium Reinhardt 1867
# Characidium Reinhardt 1867
# Leporinus fasciatus (Bloch 1794)
# Pimelodus maculatus Lcepède 1803
# Pterolebias longipinnis Garman 1895
# Roeboides microlepis (Reinhardt 1851)
# Moenkhausia dichroura (Kner 1858)
# Potamorhina squamoralevis (Braga & Azpelicueta 1983)
# Bujurquina vittata (Heckel 1840)
# Astyanax lacustris (Lütken 1875)
# Eigenmannia virescens (Valenciennes 1836)
# Hoplias malabaricus (Bloch 1794)
# Serrapinnus piaba (Lütken 1875)
# Holoshesthes pequira (Steindachner 1882)
# Cyphocharax gillii (Eigenmann & Kennedy 1903)
# Bryconamericus Eigenmann 1907
# Auchenipterus nuchalis (Spix & Agassiz 1829)
# Satanoperca pappaterra (Heckel 1840)
# Catathyridium jenynsii (Günther 1862)
# Tatia Miranda Ribeiro 1911
# Trachelyopterus striatulus (Steindachner 1877)
# Galeocharax gulo (Cope 1870)
# Saxatilia lepidota (Heckel 1840)
# Odontostilbe paraguayensis Eigenmann & Kennedy 1903
# Psalidodon fasciatus (Cuvier 1819)
# Astyanax lineatus (Perugia 1891)
# Hoplerythrinus unitaeniatus (Spix & Agassiz 1829)
# Astyanax bimaculatus (Linnaeus 1758)
# Metynnis mola Eigenmann & Kennedy 1903
# Loricaria cataphracta Linnaeus 1758
# Steindachnerina brevipinna (Eigenmann & Eigenmann 1889)
# Hemigrammus ulreyi (Boulenger 1895)
# Trichomycterus Valenciennes 1832
# Hemiodus orthonops Eigenmann & Kennedy 1903
# Melanorivulus punctatus (Boulenger 1895)
# Trichomycterus corduvensis Weyenbergh 1877
# Platydoras armatulus (Valenciennes 1840)
# Moenkhausia dichroura (Kner 1858)
# Piaractus mesopotamicus (Holmberg 1887)
# Hemigrammus Gill 1858
# Trichomycterus atochae (Allen 1942)
# Poecilia hasemani (Henn 1916)
# Astyanax lacustris (Lütken 1875)
# Parodon carrikeri Fowler 1840
# Psectrogaster curviventris Eigenmann & Kennedy 1903
# Serrasalmus Lacepède 1803
# Pyxiloricaria Isbrücker & Nijssen 1984
# Characidium Reinhardt 1867
# Characidae Latreille 1825
# Hypostomus cochliodon Kner 1854
# Corydoras aurofrenatus Eigenmann & Kennedy 1903
# Rhamdia quelen (Quoy & Gaimard 1824)
# Leporinus Agassiz 1829
# Melanorivulus punctatus (Boulenger 1895)
# Astyanax Baird & Girard 1854
# Poecilia hasemani (Henn 1916)
# Bario sanctaefilomenae (Steindachner 1907)
# Moenkhausia dichroura (Kner 1858)
# Astyanax bimaculatus (Linnaeus 1758)
# Piabucus melanostoma Holmberg 1891
# Potamotrygon motoro (Müller & Henle 1841)
# Myloplus levis (Eigenmann & McAtee 1907)
# Astyanax bimaculatus (Linnaeus 1758)
# Bryconops Kner 1858
# Saxatilia lepidota (Heckel 1840)
# Parodon carrikeri Fowler 1840
# Parodon carrikeri Fowler 1840
# Aphyocharax nattereri (Steindachner 1882)
# Anadoras weddellii (Castelnau 1855)
# Hypostomus robinii Valenciennes 1840
# Acrobrycon tarijae Fowler 1940
# Serrasalmus spilopleura 1858
# Paraloricaria Isbrücker 1979
# Psalidodon rutilus (Jenyns 1842)
# Abramites hypselonotus (Günther 1868)
# Curimatella dorsalis (Eigenmann & Eigenmann 1889)
# Astyanax bimaculatus (Linnaeus 1758)
# Catoprion mento (Cuvier 1819)
# Pimelodella gracilis (Valenciennes 1835)
# Auchenipterus nuchalis (Spix & Agassiz 1829)
# Potamotrygon motoro (Müller & Henle 1841)
# Holoshesthes pequira (Steindachner 1882)
# Piabina thomasi (Fowler 1940)
# Potamorhina squamoralevis (Braga & Azpelicueta 1983)
# Eigenmannia Jordan & Evermann 1896
# Gymnogeophagus balzanii (Pearson 1891)
# Steindachnerina dobula (Günther 1868)
# Hoplias malabaricus (Bloch 1794)
# Psalidodon rutilus (Jenyns 1842)
# Bryconamericus Eigenmann 1907
# Astyanax Baird & Girard 1854
# Rhaphiodon vulpinus Spix & Agassiz
# Aphyocharax anisitsi Eigenmann & Kennedy 1903
# Hypostomus punctatus Valenciennes 1840
# Triportheus nematurus (Kner 1858)
# Ctenobrycon kennedyi (Eigenmann 1903)
# Bryconops Kner 1858
# Hoplias malabaricus (Bloch 1794)
# Megalonema platanum (Günther 1880)
# Bryconamericus exodon Eigenmann 1907
# Pimelodus argenteus Perugia 1891
# Characidium Reinhardt 1867
# Erythrinus erythrinus (Bloch & Schneider 1801)
# Trachelyopterus Valenciennes 1840
# Steindachnerina consersa (Holmberg 1891)
# Astyanax Baird & Girard 1854
# Holoshesthes pequira (Steindachner 1882)
# Auchenipterus nuchalis (Spix & Agassiz 1829)
# Pygocentrus nattereri Kner 1858
# Bryconops melanurus (Bloch 1974)
# Hypoptopoma inexspectacum (Holmberg 1893)
# Serrasalmus spilopleura 1858
# Crenicichla semifasciata (Heckel 1840)
# Trachelyopterus Valenciennes 1840
# Bryconamericus iheringii (Boulenger 1887)
# Bario sanctaefilomenae (Steindachner 1907)
# Megalechis thoracata (Valenciennes 1840)
# Rineloricaria Bleeker 1862
# Eigenmannia trilineata López & Castello 1966
# Trichomycterus borellii Boulenger 1897
# Astyanax abramis (Jenyns 1842)
# Bunocephalus doriae Boulenger 1902
# Saxatilia lepidota (Heckel 1840)
# Glyptoperichthys Weber 1991
# Aphyocharax anisitsi Eigenmann & Kennedy 1903
# Trachelyopterus striatulus (Steindachner 1877)
# Lepidosiren paradoxa Fitzinger 1837
# Pterygoplichthys ambrosettii (Holmberg 1893)
# Lepthoplosternum Reis 1997
# Ancistrus Kner 1854
# Holoshesthes pequira (Steindachner 1882)
# Bujurquina vittata (Heckel 1840)
# Bujurquina Kullander 1986
# Piaractus brachypomus (Cuvier 1818)
# Psalidodon rivularis (Lütken 1875)
# Trichomycterus corduvensis Weyenbergh 1877
# Cetopsis Agassiz 1829
# Sternopygus macrurus (Bloch & Schneider)
# Otocinclus vittatus Regan 1904
# Spatuloricaria evansii (Boulenger 1892)
# Triportheus nematurus (Kner 1858)
# Aphyocharax nattereri (Steindachner 1882)
# Ctenobrycon kennedyi (Eigenmann 1903)
# Microglanis cottoides (Boulenger 1891)
# Serrasalmus marginatus Valenciennes 1837
# Rineloricaria catamarcensis (Berg 1895)
# Aphyocheirodon Eigenmann 1915
# Hypoptopoma inexspectacum (Holmberg 1893)
# Moenkhausia intermedia Eigenmann 1908
# Phenacogaster tegatus (Eigenmann 1911)
# Pimelodus argenteus Perugia 1891
# Pterygoplichthys ambrosettii (Holmberg 1893)
# Hoplosternum Gill 1858
# Gymnocorymbus ternetzi (Boulenger 1895)
# Tetragonopterus argenteus Cuvier 1816
# Megalamphodus eques (Steindachner 1882)
# Astyanax bimaculatus (Linnaeus 1758)
# Characidium Reinhardt 1867
# Tetragonopterus argenteus Cuvier 1816
# Apistogramma trifasciata (Eigenmann & Kennedy 1903)
# Ctenobrycon kennedyi (Eigenmann 1903)
# Triportheus Cope 1850
# Metynnis mola Eigenmann & Kennedy 1903
# Holoshesthes pequira (Steindachner 1882)
# Pseudobunocephalus rugosus (Eigenmann & Kennedy 1903)
# Salminus brasiliensis (Cuvier 1816)
# Gymnotus carapo Linnaeus 1758
# Apistogramma commbrae (Regan 1906)
# Pterodoras granulosus (Valenciennes 1821)
# Characidium borellii (Boulenger 1895)
# Odontostilbe microcephala Eigenmann 1907
# Odontostilbe Cope 1870
# Synbranchus marmoratus Bloch 1795
# Crenicichla lacustris (Castelnau 1855)
# Lepthoplosternum pectorale (Boulenger 1895)
# Poecilia hasemani (Henn 1916)
# Odontostilbe paraguayensis Eigenmann & Kennedy 1903
# Pterodoras granulosus (Valenciennes 1821)
# Metynnis maculatus (Kner 1858)
# Triportheus nematurus (Kner 1858)
# Aphyocharax rathbuni Eigenmann 1907
# Aphyocharax rathbuni Eigenmann 1907
# Markiana nigripinnis (Perugia 1891)
# Astyanax lineatus (Perugia 1891)
# Bujurquina vittata (Heckel 1840)
# Cnesterodon decemmaculatus (Jenyns 1842)
# Ancistrus cirrhosus (Valenciennes 1836)
# Serrasalmus marginatus Valenciennes 1837
# Bujurquina oenolaemus Kullander 1987
# Jenynsia lineata (Jenyns 1842)
# Astyanax Baird & Girard 1854
# Ochmacanthus batrachostoma (Miranda Ribeiro 1912)
# Tetragonopterus argenteus Cuvier 1816
# Heptapterus mustelinus (Valenciennes 1835)
# Moenkhausia dichroura (Kner 1858)
# Simpsonichthys Carvalho 1959
# Pimelodella mucosa Eigenmann & Ward 1907
# Rhamphichthys rostratus (Linnaeus 1766)
# Rineloricaria Bleeker 1862
# Psalidodon alleni (Eigenmann & McAtee 1907)
# Acestrorhynchus pantaneiro Menezes 1992
# Ctenobrycon kennedyi (Eigenmann 1903)
# Aphyocharax gracilis Fowler 1940
# Characidium Reinhardt 1867
# Psalidodon rutilus (Jenyns 1842)
# Hoplias malabaricus (Bloch 1794)
# Trichomycterus duellmani Arratia & Menu-Marque 1984
# Hoplisoma paleatum (Jenyns 1842)
# Ancistrus Kner 1854
# Roeboides microlepis (Reinhardt 1851)
# Osteogaster microps (Eigenmann & Kennedy 1903)
# Trachelyopterus Valenciennes 1840
# Sorubim lima (Bloch & Schneider 1801)
# Brycon orbignyanus (Valenciennes 1850)
# Gymnogeophagus balzanii (Pearson 1891)
# Osteogaster aenea (Gill 1858)
# Saxatilia lepidota (Heckel 1840)
# Steindachnerina brevipinna (Eigenmann & Eigenmann 1889)
# Sternopygus Müller & Troschel 1846
# Sorubim lima (Bloch & Schneider 1801)
# Saxatilia lepidota (Heckel 1840)
# Hemigrammus ulreyi (Boulenger 1895)
# Leporinus Agassiz 1829
# Apistogramma borellii (Regan 1906)
# Characidium fasciatum Reinhardt 1867
# Characidium fasciatum Reinhardt 1867
# Ancistrus cirrhosus (Valenciennes 1836)
# Characidae Latreille 1825
# Steindachnerina dobula (Günther 1868)
# Serrapinnus calliurus (Boulenger 1900)
# Cichlasoma portalegrense (Hensel 1870)
# Roeboides microlepis (Reinhardt 1851)
# Eigenmannia virescens (Valenciennes 1836)
# Gastrodermus hastatus (Eigenmann & Eigenmann 1888)
# Cheirodontinae
# Astyanax abramis (Jenyns 1842)
# Geophagus Heckel 1840
# Hemigrammus lunatus Durbin 1918
# Loricaria luciae Thomas, Rodriguez, Carvallaro, Froehlich & Castro
# Moenkhausia Eigenmann 1903
# Pimelodella Eigenmann & Eigenmann 1888
# Aequidens plagiozonatus Kullander 1984
# Oxydoras kneri Bleeker 1862
# Characidium laterale (Boulenger 1895)
# Megalechis Reis 1997
# Characidium Reinhardt 1867
# Serrapinnus piaba (Lütken 1875)
# Acestrorhynchus altus Menezes 1969
# Potamorrhaphis Miranda Ribeiro 1915
# Prochilodus lineatus (Valenciennes 1837)
# Aequidens plagiozonatus Kullander 1984
# Pinirampus pirinampu (Spix & Agassiz 1829)
# Prionobrama paraguayensis (Eigenmann 1914)
# Astyanax Baird & Girard 1854
# Apistogramma Regan 1913
# Piabucus melanostoma Holmberg 1891
# Loricaria cataphracta Linnaeus 1758
# Serrapinnus calliurus (Boulenger 1900)
# Serrasalmus marginatus Valenciennes 1837
# Brachyhypopomus brevirostris (Steindachner 1868)
# Mesonauta festivus (Heckel 1840)
# Rhamphichthys rostratus (Linnaeus 1766)
# Trachydoras Eigenmann 1925
# Astronotus crassipinnis (Heckel 1840)
# Corydoras Lacepède 1803
# Metynnis otuquensis Ahl 1924
# Triportheus nematurus (Kner 1858)
# Monotocheirodon Eigenmann & Pearson 1924
# Ituglanis eichhorniarum (Miranda Ribeiro 1912)
# Psalidodon rivularis (Lütken 1875)
# Prionobrama paraguayensis (Eigenmann 1914)
# Bujurquina oenolaemus Kullander 1987
# Loricariichthys Bleeker 1862
# Hoplias malabaricus (Bloch 1794)
# Astyanax bimaculatus (Linnaeus 1758)
# Loricariichthys maculatus (Bloch 1794)
# Hypoptopoma inexspectacum (Holmberg 1893)
# Rhamdia Bleeker 1858
# Parodon carrikeri Fowler 1840
# Pseudohemiodon Bleeker 1862
# Cichlasoma dimerus (Heckel 1840)
# Bario sanctaefilomenae (Steindachner 1907)
# Bryconamericus exodon Eigenmann 1907
# Charax leticiae Lucena 1987
# Curimatella dorsalis (Eigenmann & Eigenmann 1889)
# Bujurquina oenolaemus Kullander 1987
# Thoracocharax stellatus (Kner 1858)
# Megalamphodus eques (Steindachner 1882)
# Serrasalmus marginatus Valenciennes 1837
# Characidium bolivianum Pearson 1924
# Farlowella knerii (Steindachner 1882)
# Acestrorhynchus pantaneiro Menezes 1992
# Hemibrycon Günther 1864
# Brochis britskii Nijssen & Isbrücker 1983
# Psalidodon fasciatus (Cuvier 1819)
# Serrasalmus marginatus Valenciennes 1837
# Cyphocharax gillii (Eigenmann & Kennedy 1903)
# Astyanax Baird & Girard 1854
# Aphyocheirodon hemigrammus Eigenmann 1915
# Curimata Bosc 1817
# Roeboides descalvadensis Fowler 1932
# Ossancora eigenmanni (Boulenger 1895)
# Leporinus lacustris Amaral Campos 1945
# Characidium Reinhardt 1867
# Sternopygus macrurus (Bloch & Schneider)
# Microschemobrycon Eigenmann 1915
# Zungaro jahu (Ihering 1898)
# Psalidodon fasciatus (Cuvier 1819)
# Roeboides descalvadensis Fowler 1932
# Steindachnerina brevipinna (Eigenmann & Eigenmann 1889)
# Eigenmannia Jordan & Evermann 1896
# Brycon orbignyanus (Valenciennes 1850)
# Brachyhypopomus Mago-Leccia 1994
# Cyphocharax gillii (Eigenmann & Kennedy 1903)
# Cichlasoma boliviense Kullander 1983
# Poeciliidae
# Steindachnerina brevipinna (Eigenmann & Eigenmann 1889)
# Bujurquina oenolaemus Kullander 1987
# Bujurquina vittata (Heckel 1840)
# Moenkhausia dichroura (Kner 1858)
# Rineloricaria steinbachi (Regan 1906)
# Hoplias malabaricus (Bloch 1794)
# Roeboides affinis (Günther 1868)
# Moenkhausia dichroura (Kner 1858)
# Hypostomus cochliodon Kner 1854
# Otocinclus vittatus Regan 1904
# Heptapterus Bleeker 1858
# Cetopsis starnesi Vari, Ferraris & de Pinna 2005
# Brachyhypopomus Mago-Leccia 1994
# Trichomycteridae
# Hypostomus borellii (Boulenger 1897)
# Acestrorhynchus pantaneiro Menezes 1992
# Laetacara dorsigera (Heckel 1840)
# Spatuloricaria Schultz 1944
# Parodon carrikeri Fowler 1840
# Bario sanctaefilomenae (Steindachner 1907)
# Apareiodon affinis (Steindachner 1879)
# Pimelodus argenteus Perugia 1891
# Pseudoplatystoma fasciatum (Linnaeus 1766)
# Pimelodella mucosa Eigenmann & Ward 1907
# Serrasalmus Lacepède 1803
# Hemigrammus lunatus Durbin 1918
# Pseudoplatystoma corruscans (Spix & Agassiz 1829)
# Steindachnerina brevipinna (Eigenmann & Eigenmann 1889)
# Bujurquina vittata (Heckel 1840)
# Pimelodus blochii Valenciennes 1840
# Astyanacinus moorii (Boulenger 1892)
# Leporellus Lütken 1875
# Charax gibbosus (Linnaeus 1758)
# Astyanax abramis (Jenyns 1842)
# Moenkhausia Eigenmann 1903
# Bujurquina vittata (Heckel 1840)
# Lepthoplosternum pectorale (Boulenger 1895)
# Pterolebias Garman 1895
# Crenicichla semifasciata (Heckel 1840)
# Odontostilbe Cope 1870
# Pterolebias Garman 1895
# Curimatella dorsalis (Eigenmann & Eigenmann 1889)
# Piabina thomasi (Fowler 1940)
# Megalechis thoracata (Valenciennes 1840)
# Poptella paraguayensis (Eigenmann 1907)
# Trichomycterus duellmani Arratia & Menu-Marque 1984
# Bunocephalus Kner 1955
# Hoplias malabaricus (Bloch 1794)
# Hemigrammus lunatus Durbin 1918
# Crenicichla vittata Heckel 1840
# Rineloricaria phoxocephala (Eigenmann & Eigenmann 1889)
# Poptella paraguayensis (Eigenmann 1907)
# Acestrorhynchus falcatus (Bloch 1794)
# Hemigrammus ulreyi (Boulenger 1895)
# Trichomycterus duellmani Arratia & Menu-Marque 1984
# Trichomycterus borellii Boulenger 1897
# Megalamphodus eques (Steindachner 1882)
# Odontostilbe microcephala Eigenmann 1907
# Sturisoma barbatum (Kner 1853)
# Characidium Reinhardt 1867
# Hoplerythrinus unitaeniatus (Spix & Agassiz 1829)
# Apareiodon affinis (Steindachner 1879)
# Serrasalmus spilopleura 1858
# Saxatilia lepidota (Heckel 1840)
# Pimelodella gracilis (Valenciennes 1835)
# Saxatilia lepidota (Heckel 1840)
# Trachelyopterus Valenciennes 1840
# Odontostilbe microcephala Eigenmann 1907
# Ancistrus Kner 1854
# Megaleporinus obtusidens (Valenciennes 1837)
# Synbranchus marmoratus Bloch 1795
# Steindachnerina brevipinna (Eigenmann & Eigenmann 1889)
# Metynnis mola Eigenmann & Kennedy 1903
# Rineloricaria parva (Boulenger 1895)
# Aphyocharax rathbuni Eigenmann 1907
# Pyrrhulina australis Eigenmann & Kennedy 1903
# Rhamdia quelen (Quoy & Gaimard 1824)
# Bario sanctaefilomenae (Steindachner 1907)
# Metynnis mola Eigenmann & Kennedy 1903
# Gymnotus carapo Linnaeus 1758
# Pterygoplichthys ambrosettii (Holmberg 1893)
# Roeboides affinis (Günther 1868)
# Poeciliidae
# Bryconops Kner 1858
# Apareiodon affinis (Steindachner 1879)
# Pseudobunocephalus iheringii (Boulenger 1891)
# Loricaria Linnaeus 1758
# Pygocentrus nattereri Kner 1858
# Psalidodon fasciatus (Cuvier 1819)
# Cheirodontinae
# Oligosarcus bolivianus (Fowler 1940)
# Steindachnerina consersa (Holmberg 1891)
# Schizodon isognathus Kner 1858
# Hypostomus borellii (Boulenger 1897)
# Trichomycterus Valenciennes 1832
# Poptella paraguayensis (Eigenmann 1907)
# Leporinus lacustris Amaral Campos 1945
# Moenkhausia dichroura (Kner 1858)
# Tetragonopterus argenteus Cuvier 1816
# Serrasalmus spilopleura 1858
# Leporinus lacustris Amaral Campos 1945
# Pimelodus Lacepède 1803
# Loricariichthys Bleeker 1862
# Oxydoras kneri Bleeker 1862
# Pimelodus ornatus Kner 1858
# Charax leticiae Lucena 1987
# Synbranchus marmoratus Bloch 1795
# Psalidodon fasciatus (Cuvier 1819)
# Potamorrhaphis Miranda Ribeiro 1915
# Brycon Müller & Troschel 1844
# Salminus brasiliensis (Cuvier 1816)
# Serrasalmus Lacepède 1803
# Saxatilia lepidota (Heckel 1840)
# Aequidens plagiozonatus Kullander 1984
# Mylossoma duriventre (Cuvier 1818)
# Steindachnerina binotata (Pearson 1924)
# Piaractus mesopotamicus (Holmberg 1887)
# Metynnis mola Eigenmann & Kennedy 1903
# Moenkhausia intermedia Eigenmann 1908
# Mylossoma duriventre (Cuvier 1818)
# Pterygoplichthys ambrosettii (Holmberg 1893)
# Prionobrama paraguayensis (Eigenmann 1914)
# Gymnotus carapo Linnaeus 1758
# Crenicichla semifasciata (Heckel 1840)
# Loricaria Linnaeus 1758
# Trachydoras paraguayensis (Eigenmann & Ward 1907)
# Apistogramma trifasciata (Eigenmann & Kennedy 1903)
# Trachelyopterus Valenciennes 1840
# Bujurquina vittata (Heckel 1840)
# Bujurquina oenolaemus Kullander 1987
# Laetacara dorsigera (Heckel 1840)
# Luciopimelodus pati (Valenciennes 1835)
# Trachycorystes Bleeker 1858
# Oligosarcus bolivianus (Fowler 1940)
# Rhinodoras dorbignyi (Kner 1855)
# Bujurquina oenolaemus Kullander 1987
# Hoplosternum littorale (Hancock 1828)
# Aphyocharax anisitsi Eigenmann & Kennedy 1903
# Hypoptopoma inexspectacum (Holmberg 1893)
# Bario sanctaefilomenae (Steindachner 1907)
# Odontostilbe microcephala Eigenmann 1907
# Parodon carrikeri Fowler 1840
# Astyanax bimaculatus (Linnaeus 1758)
# Pimelodella gracilis (Valenciennes 1835)
# Acestrorhynchus pantaneiro Menezes 1992
# Rhamdia quelen (Quoy & Gaimard 1824)
# Steindachnerina brevipinna (Eigenmann & Eigenmann 1889)
# Bario sanctaefilomenae (Steindachner 1907)
# Serrapinnus microdon (Eigenmann 1915)
# Saxatilia lepidota (Heckel 1840)
# Hemigrammus ulreyi (Boulenger 1895)
# Markiana nigripinnis (Perugia 1891)
# Brachyhypopomus brevirostris (Steindachner 1868)
# Hemigrammus lunatus Durbin 1918
# Aphyocharax gracilis Fowler 1940
# Hypostomus borellii (Boulenger 1897)
# Roeboides descalvadensis Fowler 1932
# Hemigrammus ulreyi (Boulenger 1895)
# Synbranchus marmoratus Bloch 1795
# Otocinclus Cope 1871
# Leporinus lacustris Amaral Campos 1945
# Cheirodontinae
# Bujurquina oenolaemus Kullander 1987
# Astyanax lineatus (Perugia 1891)
# Trachelyopterus galeatus (Linnaeus)
# Astyanax bimaculatus (Linnaeus 1758)
# Serrasalmus Lacepède 1803
# Metynnis mola Eigenmann & Kennedy 1903
# Poeciliidae
# Brachyhypopomus brevirostris (Steindachner 1868)
# Megalamphodus eques (Steindachner 1882)
# Pimelodus Lacepède 1803
# Synbranchus marmoratus Bloch 1795
# Pimelodus blochii Valenciennes 1840
# Serrapinnus calliurus (Boulenger 1900)
# Pterolebias phasianus Costa 1988
# Hemigrammus ulreyi (Boulenger 1895)
# Pimelodella mucosa Eigenmann & Ward 1907
# Acestrorhynchus altus Menezes 1969
# Aphyocharax gracilis Fowler 1940
# Hypostomus borellii (Boulenger 1897)
# Poeciliidae
# Characidium Reinhardt 1867
# Corydoras aurofrenatus Eigenmann & Kennedy 1903
# Characidae Latreille 1825
# Characidium Reinhardt 1867
# Astyanax Baird & Girard 1854
# Metynnis otuquensis Ahl 1924
# Prochilodus lineatus (Valenciennes 1837)
# Saxatilia lepidota (Heckel 1840)
# Pimelodella Eigenmann & Eigenmann 1888
# Holoshesthes pequira (Steindachner 1882)
# Trichomycterus borellii Boulenger 1897
# Tetragonopterus argenteus Cuvier 1816
# Apistogramma borellii (Regan 1906)
# Acestrorhynchus pantaneiro Menezes 1992
# Ceratobranchia Eigenman 1914
# Rhinodoras dorbignyi (Kner 1855)
# Synbranchus marmoratus Bloch 1795
# Trichomycterus duellmani Arratia & Menu-Marque 1984
# Roeboides descalvadensis Fowler 1932
# Bujurquina vittata (Heckel 1840)
# Megalamphodus eques (Steindachner 1882)
# Gymnocorymbus ternetzi (Boulenger 1895)
# Hypoptopoma Günther 1868
# Bryconamericus Eigenmann 1907
# Leporinus striatus Kner 1858
# Psalidodon pellegrini (Eigenmann 1907)
# Loricaria cataphracta Linnaeus 1758
# Serrasalmus serrulatus (Valenciennes 1850)
# Platydoras costatus (Linnaeus 1758)
# Ctenobrycon kennedyi (Eigenmann 1903)
# Gastrodermus hastatus (Eigenmann & Eigenmann 1888)
# Hoplosternum littorale (Hancock 1828)
# Cynopotamus argenteus (Valenciennes 1837)
# Eigenmannia trilineata López & Castello 1966
# Prochilodus lineatus (Valenciennes 1837)
# Astyanax bimaculatus (Linnaeus 1758)
# Potamorhina squamoralevis (Braga & Azpelicueta 1983)
# Aphyocharax gracilis Fowler 1940
# Acrobrycon tarijae Fowler 1940
# Apistogramma commbrae (Regan 1906)
# Callichthys callichthys (Linnaeus 1758)
# Curimatella dorsalis (Eigenmann & Eigenmann 1889)
# Pyrrhulina brevis Steindachner 1876
# Farlowella nattereri Steindachner 1910
# Gymnogeophagus balzanii (Pearson 1891)
# Cichlasoma boliviense Kullander 1983
# Ancistrus Kner 1854
# Bario sanctaefilomenae (Steindachner 1907)
# Megalamphodus eques (Steindachner 1882)
# Hypoptopoma inexspectacum (Holmberg 1893)
# Ancistrus Kner 1854
# Loricaria cataphracta Linnaeus 1758
# Bario sanctaefilomenae (Steindachner 1907)
# Sternopygus macrurus (Bloch & Schneider)
# Chaetobranchopsis australis Eigenmann & Ward 1907
# Hypostomus borellii (Boulenger 1897)
# Aequidens Eigenmann & Bray 1894
# Leporinus lacustris Amaral Campos 1945
# Cichlasoma portalegrense (Hensel 1870)
# Megalechis thoracata (Valenciennes 1840)
# Anadoras weddellii (Castelnau 1855)
# Odontostilbe microcephala Eigenmann 1907
# Acrobrycon tarijae Fowler 1940
# Trichomycteridae
# Laetacara dorsigera (Heckel 1840)
# Rineloricaria Bleeker 1862
# Moenkhausia dichroura (Kner 1858)
# Serrasalmus marginatus Valenciennes 1837
# Hypostomus borellii (Boulenger 1897)
# Pseudocheirodon Meek & Hildebrand 1916
# Saxatilia lepidota (Heckel 1840)
# Leporinus fasciatus (Bloch, 1794)
# Parodon Valenciennes 1850
# Monotocheirodon Eigenmann & Pearson 1924
# Rhinodoras dorbignyi (Kner 1855)
# Parodon suborbitalis Valenciennes 1850
# Ancistrus bufonius (Valenciennes 1840)
# Trachelyopterus Valenciennes 1840
# Poecilia hasemani (Henn 1916)
# Acrobrycon tarijae Fowler 1940
# Characidium Reinhardt 1867
# Cnesterodon decemmaculatus (Jenyns 1842)
# Acrobrycon Eigenmann & Pearson 1924
# Serrapinnus calliurus (Boulenger 1900)
# Megaleporinus trifasciatus (Steindachner 1876)
# Serrapinnus calliurus (Boulenger 1900)
# Moenkhausia dichroura (Kner 1858)
# Rhamdia Bleeker 1858
# Prionobrama paraguayensis (Eigenmann 1914)
# Serrapinnus calliurus (Boulenger 1900)
# Auchenipterus nuchalis (Spix & Agassiz 1829)
# Gastrodermus hastatus (Eigenmann & Eigenmann 1888)
# Lepthoplosternum Reis 1997
# Roeboides Günther 1864
# Psalidodon alleni (Eigenmann & McAtee 1907)
# Pimelodus ornatus Kner 1858
# Curimatopsis myersi Vari 1982
# Loricariichthys platymetopon Isbrücker & Nijssen 1979
# Gastrodermus hastatus (Eigenmann & Eigenmann 1888)
# Hoplias malabaricus (Bloch 1794)
# Oligosarcus bolivianus (Fowler 1940)
# Megalechis thoracata (Valenciennes 1840)
# Hypostomus Lacepède 1803
# Hoplosternum littorale (Hancock 1828)
# Hoplerythrinus unitaeniatus (Spix & Agassiz 1829)
# Cheirodontinae
# Poptella paraguayensis (Eigenmann 1907)
# Pimelodella mucosa Eigenmann & Ward 1907
# Astyanax bimaculatus (Linnaeus 1758)
# Pyrrhulina australis Eigenmann & Kennedy 1903
# Leporinus friderici (Bloch 1794)
# Pyrrhulina australis Eigenmann & Kennedy 1903
# Luciopimelodus pati (Valenciennes 1835)
# Schizodon borellii (Boulenger 1900)
# Parodon carrikeri Fowler 1840
# Apistogramma Regan 1913
# Steindachnerina brevipinna (Eigenmann & Eigenmann 1889)
# Serrapinnus calliurus (Boulenger 1900)
# Hypostomus Lacepède 1803
# Brachyhypopomus Mago-Leccia 1994
# Charax leticiae Lucena 1987
# Charax gibbosus (Linnaeus 1758)
# Brycon orbignyanus (Valenciennes 1850)
# Crenicichla semifasciata (Heckel 1840)
# Pseudoplatystoma fasciatum (Linnaeus 1766)
# Roeboides descalvadensis Fowler 1932
# Triportheus nematurus (Kner 1858)
# Bujurquina oenolaemus Kullander 1987
# Cichlasoma portalegrense (Hensel 1870)
# Acestrorhynchus pantaneiro Menezes 1992
# Characidium fasciatum Reinhardt 1867
# Acaronia Myers 1940
# Apistogramma borellii (Regan 1906)
# Serrapinnus kriegi (Schindler 1937)
# Brycon Müller & Troschel 1844
# Loricariichthys Bleeker 1862
# Plagioscion ternetzi Boulenger 1895
# Aphyocharax dentatus Eigenmann & Kennedy 1903
# Odontostilbe microcephala Eigenmann 1907
# Characidae Latreille 1825
# Loricaria cataphracta Linnaeus 1758
# Serrasalmus Lacepède 1803

# %%
unique_scientific_names = {str(row['dwc_scientificName']) for row in results}
for species_name in unique_scientific_names:
    positive_list = [
        row for row in results 
        if "present" in str(row['dwc_occurrenceStatus'])
    ]
positive_scientific_names = {str(row['dwc_scientificName']) for row in positive_list}
    
for species_name in unique_scientific_names:
    negative_list = [
        row for row in results 
        if "absent" in str(row['dwc_occurrenceStatus'])
    ]
negative_scientific_names = {str(row['dwc_scientificName']) for row in negative_list}

# Collect unique scientific names in a set
unique_family_names = {str(row['dwc_family']) for row in results}

# Sort the unique names alphabetically
sorted_family_names = sorted(unique_family_names)

# Print each scientific name
for name in sorted_family_names:
    print(name)
    filtered_results = [
        row for row in results 
        if name in str(row['dwc_family'])
    ]
    unique_scientific_names = {str(row['dwc_scientificName']) for row in filtered_results}
    sorted_scientific_names = sorted(unique_scientific_names - negative_scientific_names)
    for species_name in sorted_scientific_names:
        filtered_results_2 = [
            row for row in filtered_results 
            if species_name in str(row['dwc_scientificName'])
        ]
        #print(filtered_results_2)
        type_set = {str(row['dc_type']) for row in filtered_results_2}
        string = "Text"
        type_x = ""
        if string in type_set:
            type_x = " listing"
        string = "PhysicalObject"
        type_y = ""
        if string in type_set:
            type_y = " observation"
        string = "StillImage"
        type_z = ""
        if string in type_set:
            type_z = " illustration"
        catalogNumber_set = {str(row['dwc_catalogNumber']) for row in filtered_results_2}
        #print(catalogNumber_set)
        catalog = ""
        string = "None"
        if catalogNumber_set != {string}:
            catalog = " specimen"
        else:
            catalog = ""
        print("\t" + species_name + ":" + type_x + type_y + type_z + catalog)
        '''
        unique_verbatim_names = {str(row['dwc_verbatimIdentification']) for row in filtered_results_2}
        sorted_verbatim_names = sorted(unique_verbatim_names)
        for verbatim_name in sorted_verbatim_names:
            print("\t" + "\t" + verbatim_name)
        '''
# Out:
# Acestrorhamphidae
# 	Astyanacinus moorii (Boulenger 1892): listing observation
# 	Astyanax Baird & Girard 1854: listing observation
# 	Astyanax abramis (Jenyns 1842): listing observation
# 	Astyanax lacustris (Lütken 1875): observation specimen
# 	Astyanax lineatus (Perugia 1891): listing observation
# 	Ctenobrycon kennedyi (Eigenmann 1903): listing observation specimen
# 	Gymnocorymbus ternetzi (Boulenger 1895): listing observation
# 	Hemigrammus Gill 1858: listing
# 	Hemigrammus lunatus Durbin 1918: listing observation
# 	Hemigrammus ulreyi (Boulenger 1895): listing observation specimen
# 	Hyphessobrycon Durbin 1908: listing
# 	Megalamphodus eques (Steindachner 1882): listing observation
# 	Moenkhausia Eigenmann 1903: listing
# 	Moenkhausia dichroura (Kner 1858): listing observation illustration specimen
# 	Oligosarcus bolivianus (Fowler 1940): listing observation
# 	Poptella paraguayensis (Eigenmann 1907): listing observation illustration
# 	Psalidodon alleni (Eigenmann & McAtee 1907): listing observation specimen
# 	Psalidodon pellegrini (Eigenmann 1907): listing
# 	Psalidodon rivularis (Lütken 1875): listing observation
# Acestrorhynchidae
# 	Acestrorhynchus falcatus (Bloch 1794): listing
# 	Acestrorhynchus pantaneiro Menezes 1992: listing observation
# Achiridae
# 	Catathyridium jenynsii (Günther 1862): listing
# Anablepidae
# 	Jenynsia lineata (Jenyns 1842): listing
# Anostomidae
# 	Abramites hypselonotus (Günther 1868): listing
# 	Leporellus Lütken 1875: listing
# 	Leporinus Agassiz 1829: listing
# 	Leporinus fasciatus (Bloch 1794): listing
# 	Leporinus friderici (Bloch 1794): listing
# 	Leporinus lacustris Amaral Campos 1945: listing observation
# 	Leporinus striatus Kner 1858: listing
# 	Megaleporinus obtusidens (Valenciennes 1837): listing observation
# 	Schizodon borellii (Boulenger 1900): listing
# 	Schizodon isognathus Kner 1858: listing
# Aspredinidae
# 	Bunocephalus Kner 1955: listing
# 	Bunocephalus doriae Boulenger 1902: listing
# 	Pseudobunocephalus iheringii (Boulenger 1891): listing
# 	Pseudobunocephalus rugosus (Eigenmann & Kennedy 1903): listing
# Auchenipteridae
# 	Ageneiosus inermis (Linnaeus 1766): listing
# 	Auchenipterus nigripinnis (Boulenger 1895): listing
# 	Auchenipterus nuchalis (Spix & Agassiz 1829): listing observation
# 	Entomocorus benjamini Eigenmann 1917: listing
# 	Tatia Miranda Ribeiro 1911: listing
# 	Trachelyopterus Valenciennes 1840: listing observation illustration
# 	Trachelyopterus galeatus (Linnaeus): listing observation specimen
# 	Trachelyopterus striatulus (Steindachner 1877): listing
# 	Trachycorystes Bleeker 1858: listing
# Belonidae
# 	Potamorrhaphis Miranda Ribeiro 1915: listing observation
# Bryconidae
# 	Brycon Müller & Troschel 1844: listing observation
# 	Brycon hilarii (Valenciennes 1850): listing
# 	Brycon orbignyanus (Valenciennes 1850): listing observation
# 	Salminus brasiliensis (Cuvier 1816): listing
# Callichthyidae
# 	Brochis britskii Nijssen & Isbrücker 1983: listing
# 	Callichthys callichthys (Linnaeus 1758): listing
# 	Corydoras Lacepède 1803: listing
# 	Corydoras aurofrenatus Eigenmann & Kennedy 1903: listing observation
# 	Gastrodermus hastatus (Eigenmann & Eigenmann 1888): listing observation specimen
# 	Hoplisoma paleatum (Jenyns 1842): listing
# 	Hoplisoma polystictum (Regan 1912): observation specimen
# 	Hoplosternum Gill 1858: listing
# 	Hoplosternum littorale (Hancock 1828): listing observation
# 	Lepthoplosternum Reis 1997: listing observation
# 	Lepthoplosternum pectorale (Boulenger 1895): listing observation
# 	Megalechis Reis 1997: listing observation
# 	Megalechis thoracata (Valenciennes 1840): listing observation specimen
# 	Osteogaster aenea (Gill 1858): listing
# 	Osteogaster microps (Eigenmann & Kennedy 1903): listing observation specimen
# Cetopsidae
# 	Cetopsis Agassiz 1829: listing
# 	Cetopsis starnesi Vari, Ferraris & de Pinna 2005: observation illustration specimen
# Characidae
# 	Aphyocharax Günther 1868: listing
# 	Aphyocharax anisitsi Eigenmann & Kennedy 1903: listing observation specimen
# 	Aphyocharax dentatus Eigenmann & Kennedy 1903: listing
# 	Aphyocharax gracilis Fowler 1940: listing observation illustration specimen
# 	Aphyocharax nattereri (Steindachner 1882): listing observation
# 	Aphyocharax rathbuni Eigenmann 1907: listing observation
# 	Aphyocheirodon Eigenmann 1915: listing
# 	Aphyocheirodon hemigrammus Eigenmann 1915: listing
# 	Characidae Latreille 1825: listing observation
# 	Charax leticiae Lucena 1987: listing observation
# 	Cheirodon Girard 1855: observation
# 	Cheirodontinae: listing observation
# 	Cynopotamus argenteus (Valenciennes 1837): listing
# 	Galeocharax gulo (Cope 1870): listing
# 	Holoshesthes pequira (Steindachner 1882): listing observation
# 	Microschemobrycon Eigenmann 1915: listing
# 	Odontostilbe Cope 1870: listing observation
# 	Odontostilbe microcephala Eigenmann 1907: listing observation specimen
# 	Odontostilbe paraguayensis Eigenmann & Kennedy 1903: listing observation
# 	Phenacogaster tegatus (Eigenmann 1911): listing observation
# 	Prionobrama paraguayensis (Eigenmann 1914): listing observation illustration specimen
# 	Prodontocharax Eigenmann & Pearson 1924: listing
# 	Pseudocheirodon Meek & Hildebrand 1916: listing
# 	Roeboides Günther 1864: listing
# 	Roeboides affinis (Günther 1868): listing observation
# 	Roeboides descalvadensis Fowler 1932: listing observation illustration
# 	Roeboides microlepis (Reinhardt 1851): listing observation
# 	Serrapinnus calliurus (Boulenger 1900): listing observation illustration
# 	Serrapinnus kriegi (Schindler 1937): listing
# 	Serrapinnus microdon (Eigenmann 1915): listing
# 	Serrapinnus piaba (Lütken 1875): listing observation specimen
# 	Tetragonopterus argenteus Cuvier 1816: listing observation illustration
# Cichlidae
# 	Acaronia Myers 1940: listing
# 	Aequidens Eigenmann & Bray 1894: listing
# 	Aequidens plagiozonatus Kullander 1984: listing observation
# 	Apistogramma Regan 1913: listing
# 	Apistogramma borellii (Regan 1906): listing observation
# 	Apistogramma commbrae (Regan 1906): listing observation
# 	Apistogramma taeniata (Günther 1862): listing
# 	Apistogramma trifasciata (Eigenmann & Kennedy 1903): listing observation
# 	Astronotus crassipinnis (Heckel 1840): listing
# 	Bujurquina Kullander 1986: listing
# 	Bujurquina oenolaemus Kullander 1987: listing observation illustration specimen
# 	Bujurquina vittata (Heckel 1840): listing observation
# 	Chaetobranchopsis australis Eigenmann & Ward 1907: listing observation
# 	Cichlasoma boliviense Kullander 1983: listing observation
# 	Cichlasoma dimerus (Heckel 1840): listing observation
# 	Cichlasoma portalegrense (Hensel 1870): observation
# 	Cichlidae: listing
# 	Crenicichla 1840: listing
# 	Crenicichla lacustris (Castelnau 1855): listing
# 	Crenicichla semifasciata (Heckel 1840): listing observation
# 	Crenicichla vittata Heckel 1840: listing
# 	Geophagus Heckel 1840: listing
# 	Gymnogeophagus balzanii (Pearson 1891): listing observation
# 	Laetacara dorsigera (Heckel 1840): listing observation
# 	Mesonauta festivus (Heckel 1840): listing
# 	Satanoperca pappaterra (Heckel 1840): listing
# 	Saxatilia lepidota (Heckel 1840): listing observation
# Crenuchidae
# 	Characidium Reinhardt 1867: listing observation illustration
# 	Characidium bolivianum Pearson 1924: listing
# 	Characidium borellii (Boulenger 1895): listing
# 	Characidium fasciatum Reinhardt 1867: listing observation
# 	Characidium laterale (Boulenger 1895): listing observation
# Curimatidae
# 	Curimata Bosc 1817: listing
# 	Curimatella dorsalis (Eigenmann & Eigenmann 1889): listing observation
# 	Curimatopsis myersi Vari 1982: listing
# 	Cyphocharax gillii (Eigenmann & Kennedy 1903): listing observation
# 	Potamorhina squamoralevis (Braga & Azpelicueta 1983): listing observation
# 	Psectrogaster curviventris Eigenmann & Kennedy 1903: listing
# 	Steindachnerina binotata (Pearson 1924): listing
# 	Steindachnerina brevipinna (Eigenmann & Eigenmann 1889): listing observation illustration
# 	Steindachnerina consersa (Holmberg 1891): listing observation
# 	Steindachnerina dobula (Günther 1868): listing
# Cynodontidae
# 	Rhaphiodon vulpinus Spix & Agassiz: listing
# Doradidae
# 	Anadoras weddellii (Castelnau 1855): listing
# 	Ossancora eigenmanni (Boulenger 1895): listing
# 	Oxydoras kneri Bleeker 1862: listing
# 	Platydoras Bleeker 1862: listing
# 	Platydoras armatulus (Valenciennes 1840): listing
# 	Platydoras costatus (Linnaeus 1758): listing observation specimen
# 	Pterodoras granulosus (Valenciennes 1821): listing
# 	Rhinodoras dorbignyi (Kner 1855): listing
# 	Trachydoras Eigenmann 1925: observation
# 	Trachydoras paraguayensis (Eigenmann & Ward 1907): listing
# Engraulidae
# 	Lycengraulis Günther 1868: listing
# Erythrinidae
# 	Erythrinus erythrinus (Bloch & Schneider 1801): observation
# 	Hoplerythrinus unitaeniatus (Spix & Agassiz 1829): listing
# 	Hoplias malabaricus (Bloch 1794): listing observation
# Gasteropelecidae
# 	Thoracocharax stellatus (Kner 1858): listing
# Gymnotidae
# 	Gymnotus carapo Linnaeus 1758: listing observation specimen
# Hemiodontidae
# 	Hemiodus orthonops Eigenmann & Kennedy 1903: listing
# Heptapteridae
# 	Hemisorubim platyrhynchos (Valenciennes 1840): listing
# 	Heptapterus Bleeker 1858: listing
# 	Heptapterus mustelinus (Valenciennes 1835): observation
# 	Imparfinis guttatus (Pearson 1924): listing
# 	Pimelodella Eigenmann & Eigenmann 1888: listing
# 	Pimelodella cristata (Müller & Troschel 1849): listing
# 	Pimelodella gracilis (Valenciennes 1835): listing observation
# 	Pimelodella mucosa Eigenmann & Ward 1907: listing observation illustration specimen
# 	Rhamdia Bleeker 1858: listing
# 	Rhamdia quelen (Quoy & Gaimard 1824): listing observation specimen
# Hypopomidae
# 	Brachyhypopomus Mago-Leccia 1994: listing observation
# 	Brachyhypopomus brevirostris (Steindachner 1868): listing observation specimen
# Iguanodectidae
# 	Bryconops Kner 1858: observation illustration
# 	Bryconops melanurus (Bloch 1974): listing
# 	Piabucus melanostoma Holmberg 1891: listing observation
# Lebiasinidae
# 	Lebiasinidae: listing observation
# 	Pyrrhulina australis Eigenmann & Kennedy 1903: listing observation
# 	Pyrrhulina brevis Steindachner 1876: listing
# Lepidosirenidae
# 	Lepidosiren paradoxa Fitzinger 1837: listing
# Loricariidae
# 	Ancistrus Kner 1854: listing observation
# 	Ancistrus bufonius (Valenciennes 1840): listing
# 	Ancistrus cirrhosus (Valenciennes 1836): listing
# 	Farlowella knerii (Steindachner 1882): listing
# 	Farlowella nattereri Steindachner 1910: listing
# 	Glyptoperichthys Weber 1991: listing
# 	Hypoptopoma Günther 1868: listing observation
# 	Hypoptopoma inexspectacum (Holmberg 1893): listing observation
# 	Hypostomus Lacepède 1803: listing
# 	Hypostomus borellii (Boulenger 1897): listing observation illustration
# 	Hypostomus cochliodon Kner 1854: listing observation
# 	Hypostomus punctatus Valenciennes 1840: listing
# 	Hypostomus robinii Valenciennes 1840: observation
# 	Loricaria Linnaeus 1758: listing observation
# 	Loricaria cataphracta Linnaeus 1758: listing observation
# 	Loricaria luciae Thomas, Rodriguez, Carvallaro, Froehlich & Castro: observation specimen
# 	Loricariichthys Bleeker 1862: listing observation
# 	Loricariichthys maculatus (Bloch 1794): listing
# 	Loricariichthys platymetopon Isbrücker & Nijssen 1979: listing
# 	Otocinclus Cope 1871: listing
# 	Otocinclus vestitus Cope 1872: listing
# 	Otocinclus vittatus Regan 1904: listing observation
# 	Paraloricaria Isbrücker 1979: listing
# 	Pseudohemiodon Bleeker 1862: listing
# 	Pterygoplichthys ambrosettii (Holmberg 1893): listing observation
# 	Pyxiloricaria Isbrücker & Nijssen 1984: listing
# 	Rineloricaria Bleeker 1862: listing observation
# 	Rineloricaria catamarcensis (Berg 1895): listing observation
# 	Rineloricaria parva (Boulenger 1895): listing
# 	Rineloricaria phoxocephala (Eigenmann & Eigenmann 1889): listing
# 	Rineloricaria steinbachi (Regan 1906): listing
# 	Spatuloricaria Schultz 1944: listing
# 	Spatuloricaria evansii (Boulenger 1892): listing
# 	Sturisoma Swainson 1838: listing
# 	Sturisoma barbatum (Kner 1853): listing
# Parodontidae
# 	Apareiodon affinis (Steindachner 1879): listing observation
# 	Parodon Valenciennes 1850: listing
# 	Parodon carrikeri Fowler 1840: listing observation illustration specimen
# 	Parodon suborbitalis Valenciennes 1850: listing
# Pimelodidae
# 	Luciopimelodus pati (Valenciennes 1835): listing
# 	Megalonema platanum (Günther 1880): listing
# 	Pimelodus Lacepède 1803: listing observation
# 	Pimelodus argenteus Perugia 1891: listing
# 	Pimelodus blochii Valenciennes 1840: listing
# 	Pimelodus maculatus Lcepède 1803: listing observation
# 	Pimelodus ornatus Kner 1858: listing
# 	Pinirampus pirinampu (Spix & Agassiz 1829): listing
# 	Pseudoplatystoma corruscans (Spix & Agassiz 1829): listing
# 	Pseudoplatystoma fasciatum (Linnaeus 1766): listing observation specimen
# 	Sorubim lima (Bloch & Schneider 1801): listing
# 	Zungaro jahu (Ihering 1898): listing
# 	Zungaro zungaro (Humboldt 1821): listing
# Poeciliidae
# 	Cnesterodon decemmaculatus (Jenyns 1842): listing observation
# 	Poecilia hasemani (Henn 1916): listing observation illustration specimen
# 	Poeciliidae: listing observation illustration
# Potamotrygonidae
# 	Potamotrygon motoro (Müller & Henle 1841): listing
# Pristigasteridae
# 	Pellona flavipinnis (Valenciennes 1837): listing
# Prochilodontidae
# 	Prochilodus lineatus (Valenciennes 1837): listing observation
# 	Prochilodus nigricans Spix & Agassiz 1829: listing
# Pseudopimelodidae
# 	Microglanis Eigenmann 1912: listing
# 	Microglanis cottoides (Boulenger 1891): listing
# Rhamphichthyidae
# 	Rhamphichthys pantherinus Castelnau 1855: listing
# 	Rhamphichthys rostratus (Linnaeus 1766): listing observation
# Rivulidae
# 	Melanorivulus punctatus (Boulenger 1895): listing observation specimen
# 	Pterolebias Garman 1895: listing
# 	Pterolebias longipinnis Garman 1895: observation specimen
# 	Pterolebias phasianus Costa 1988: observation specimen
# 	Simpsonichthys Carvalho 1959: listing
# 	Trichomycterus balzanii (Perugia 1891): listing
# Sciaenidae
# 	Pachyurus bonariensis Steindachner 1879: listing
# 	Plagioscion ternetzi Boulenger 1895: listing
# Serrasalmidae
# 	Catoprion mento (Cuvier 1819): listing
# 	Metynnis maculatus (Kner 1858): listing
# 	Metynnis mola Eigenmann & Kennedy 1903: listing observation illustration
# 	Metynnis otuquensis Ahl 1924: observation
# 	Myloplus levis (Eigenmann & McAtee 1907): listing
# 	Myloplus rubripinnis (Müller & Troschel 1844): listing
# 	Mylossoma duriventre (Cuvier 1818): listing
# 	Piaractus brachypomus (Cuvier 1818): listing
# 	Piaractus mesopotamicus (Holmberg 1887): listing observation
# 	Pygocentrus nattereri Kner 1858: listing observation
# 	Serrasalmus Lacepède 1803: listing observation illustration
# 	Serrasalmus marginatus Valenciennes 1837: listing observation
# 	Serrasalmus serrulatus (Valenciennes 1850): observation
# 	Serrasalmus spilopleura 1858: listing observation specimen
# Sternopygidae
# 	Eigenmannia Jordan & Evermann 1896: listing
# 	Eigenmannia trilineata López & Castello 1966: listing observation
# 	Eigenmannia virescens (Valenciennes 1836): listing observation specimen
# 	Sternopygus Müller & Troschel 1846: listing
# 	Sternopygus macrurus (Bloch & Schneider): listing observation
# Stevardiidae
# 	Acrobrycon Eigenmann & Pearson 1924: listing
# 	Acrobrycon tarijae Fowler 1940: listing observation
# 	Bryconamericus Eigenmann 1907: listing
# 	Bryconamericus exodon Eigenmann 1907: listing
# 	Bryconamericus iheringii (Boulenger 1887): listing
# 	Ceratobranchia Eigenman 1914: listing
# 	Hemibrycon Günther 1864: listing
# 	Markiana nigripinnis (Perugia 1891): listing observation
# 	Monotocheirodon Eigenmann & Pearson 1924: listing observation
# 	Piabarchus stramineus (Eigenmann 1908): listing
# 	Piabina argentea Reinhardt 1867: listing
# 	Piabina thomasi (Fowler 1940): listing observation
# Synbranchidae
# 	Synbranchus marmoratus Bloch 1795: listing observation
# Trichomycteridae
# 	Ituglanis eichhorniarum (Miranda Ribeiro 1912): observation specimen
# 	Ochmacanthus batrachostoma (Miranda Ribeiro 1912): observation specimen
# 	Trichomycteridae: listing
# 	Trichomycterus Valenciennes 1832: listing
# 	Trichomycterus atochae (Allen 1942): observation specimen
# 	Trichomycterus borellii Boulenger 1897: listing observation
# 	Trichomycterus corduvensis Weyenbergh 1877: listing observation
# 	Trichomycterus duellmani Arratia & Menu-Marque 1984: observation illustration specimen
# Triportheidae
# 	Triportheus Cope 1850: listing
# 	Triportheus nematurus (Kner 1858): listing observation

# %%
unique_scientific_names = {str(row['dwc_scientificName']) for row in results}
for species_name in unique_scientific_names:
    positive_list = [
        row for row in results 
        if "present" in str(row['dwc_occurrenceStatus'])
    ]
positive_scientific_names = {str(row['dwc_scientificName']) for row in positive_list}
    
for species_name in unique_scientific_names:
    negative_list = [
        row for row in results 
        if "absent" in str(row['dwc_occurrenceStatus'])
    ]
negative_scientific_names = {str(row['dwc_scientificName']) for row in negative_list}

# Collect unique scientific names in a set
unique_family_names = {str(row['dwc_family']) for row in results}

# Sort the unique names alphabetically
sorted_family_names = sorted(unique_family_names)

# Print each scientific name
for name in sorted_family_names:
    filtered_results = [
        row for row in results 
        if name in str(row['dwc_family'])
    ]
    unique_scientific_names = {str(row['dwc_scientificName']) for row in filtered_results}
    sorted_scientific_names = sorted(unique_scientific_names.intersection(negative_scientific_names))
    if not sorted_scientific_names:
        pass
    else:
        print(name)
        for species_name in sorted_scientific_names:
            filtered_results_2 = [
                row for row in filtered_results 
                if species_name in str(row['dwc_scientificName'])
            ]
            #print(filtered_results_2)
            type_set = {str(row['dc_type']) for row in filtered_results_2}
            string = "Text"
            type_x = ""
            if string in type_set:
                type_x = " listing"
            string = "PhysicalObject"
            type_y = ""
            if string in type_set:
                type_y = " observation"
            string = "StillImage"
            type_z = ""
            if string in type_set:
                type_z = " illustration"
            catalogNumber_set = {str(row['dwc_catalogNumber']) for row in filtered_results_2}
            #print(catalogNumber_set)
            catalog = ""
            string = "None"
            if catalogNumber_set != {string}:
                catalog = " specimen"
            else:
                catalog = ""
            print("\t" + species_name + ":" + type_x + type_y + type_z + catalog)
            '''
            unique_verbatim_names = {str(row['dwc_verbatimIdentification']) for row in filtered_results_2}
            sorted_verbatim_names = sorted(unique_verbatim_names)
            for verbatim_name in sorted_verbatim_names:
                print("\t" + "\t" + verbatim_name)
            '''
# Out:
# Acestrorhamphidae
# 	Astyanax bimaculatus (Linnaeus 1758): listing observation
# 	Bario sanctaefilomenae (Steindachner 1907): listing observation illustration specimen
# 	Moenkhausia intermedia Eigenmann 1908: listing
# 	Psalidodon fasciatus (Cuvier 1819): listing
# 	Psalidodon rutilus (Jenyns 1842): listing observation
# Acestrorhynchidae
# 	Acestrorhynchus altus Menezes 1969: listing
# Anostomidae
# 	Leporinus fasciatus (Bloch, 1794): listing
# 	Megaleporinus trifasciatus (Steindachner 1876): listing
# Characidae
# 	Charax gibbosus (Linnaeus 1758): listing

# %%
print(negative_scientific_names)
# Out:
# {'Acestrorhynchus altus Menezes 1969', 'Charax gibbosus (Linnaeus 1758)', 'Moenkhausia intermedia Eigenmann 1908', 'Megaleporinus trifasciatus (Steindachner 1876)', 'Psalidodon rutilus (Jenyns 1842)', 'Bario sanctaefilomenae (Steindachner 1907)', 'Astyanax bimaculatus (Linnaeus 1758)', 'Leporinus fasciatus (Bloch, 1794)', 'Psalidodon fasciatus (Cuvier 1819)'}

# %%
print(positive_scientific_names.intersection_update({'Oligosarcus schindleri'}))
# Out:
# None

# %%
print(positive_scientific_names)
# Out:
# set()

# %%
unique_scientific_names = {str(row['dwc_scientificName']) for row in results}
for species_name in unique_scientific_names:
    positive_list = [
        row for row in results 
        if "present" in str(row['dwc_occurrenceStatus'])
    ]
positive_scientific_names = {str(row['dwc_scientificName']) for row in positive_list}
    
for species_name in unique_scientific_names:
    negative_list = [
        row for row in results 
        if "absent" in str(row['dwc_occurrenceStatus'])
    ]
negative_scientific_names = {str(row['dwc_scientificName']) for row in negative_list}

# Collect unique scientific names in a set
unique_family_names = {str(row['dwc_family']) for row in results}

# Sort the unique names alphabetically
sorted_family_names = sorted(unique_family_names)

# Print each scientific name
for name in sorted_family_names:
    print(name)
    filtered_results = [
        row for row in results 
        if name in str(row['dwc_family'])
    ]
    unique_scientific_names = {str(row['dwc_scientificName']) for row in filtered_results}
    sorted_scientific_names = sorted(unique_scientific_names.intersection(negative_scientific_names))
    print(sorted_scientific_names)
# Out:
# Acestrorhamphidae
# ['Astyanax bimaculatus (Linnaeus 1758)', 'Bario sanctaefilomenae (Steindachner 1907)', 'Moenkhausia intermedia Eigenmann 1908', 'Psalidodon fasciatus (Cuvier 1819)', 'Psalidodon rutilus (Jenyns 1842)']
# Acestrorhynchidae
# ['Acestrorhynchus altus Menezes 1969']
# Achiridae
# []
# Anablepidae
# []
# Anostomidae
# ['Leporinus fasciatus (Bloch, 1794)', 'Megaleporinus trifasciatus (Steindachner 1876)']
# Aspredinidae
# []
# Auchenipteridae
# []
# Belonidae
# []
# Bryconidae
# []
# Callichthyidae
# []
# Cetopsidae
# []
# Characidae
# ['Charax gibbosus (Linnaeus 1758)']
# Cichlidae
# []
# Crenuchidae
# []
# Curimatidae
# []
# Cynodontidae
# []
# Doradidae
# []
# Engraulidae
# []
# Erythrinidae
# []
# Gasteropelecidae
# []
# Gymnotidae
# []
# Hemiodontidae
# []
# Heptapteridae
# []
# Hypopomidae
# []
# Iguanodectidae
# []
# Lebiasinidae
# []
# Lepidosirenidae
# []
# Loricariidae
# []
# Parodontidae
# []
# Pimelodidae
# []
# Poeciliidae
# []
# Potamotrygonidae
# []
# Pristigasteridae
# []
# Prochilodontidae
# []
# Pseudopimelodidae
# []
# Rhamphichthyidae
# []
# Rivulidae
# []
# Sciaenidae
# []
# Serrasalmidae
# []
# Sternopygidae
# []
# Stevardiidae
# []
# Synbranchidae
# []
# Trichomycteridae
# []
# Triportheidae
# []
